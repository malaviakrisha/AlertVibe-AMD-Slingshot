# %%
# ⚠️ PROTOTYPE NOTE: Documentation only - ready for execution in Colab
# === CELL 1: SETUP (18s) ===
# !pip install -q tensorflow==2.15.0 librosa==0.10.1 soundfile==0.12.1

import librosa
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
print("Environment ready!")

# === CELL 2: MFCC EXTRACTOR (5s per file) ===
def extract_mfcc(file_path, sr=16000, n_mfcc=13):
    y, _ = librosa.load(file_path, sr=sr, duration=3.0)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, n_fft=2048, hop_length=512)
    return np.mean(mfcc.T, axis=0)

print("MFCC function ready!")

# === CELL 3: DATA PREP ===
classes = ['fire_alarm', 'kettle_whistle', 'glass_shatter']
print("Upload 3-5 clips per class from freesound.org")
print("Target: 90% accuracy with 9 audio files total")
